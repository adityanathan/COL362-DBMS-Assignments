# %%
import pandas as pd

# %%
df = pd.read_csv('flights_reordered.csv')

# %%
df.insert(0, 'flightid', range(1000, 1000 + len(df)))

# %%
df
# Out:
#          flightid  originairportid  destairportid carrier  dayofmonth  \
# 0            1000            11433          13303      DL          19
# 1            1001            14869          12478      DL          19
# 2            1002            14057          14869      DL          19
# 3            1003            15016          11433      DL          19
# 4            1004            11193          12892      DL          19
# ...           ...              ...            ...     ...         ...
# 2702213   2703213            13204          14869      DL          19
# 2702214   2703214            10397          13495      DL          19
# 2702215   2703215            10140          10397      DL          19
# 2702216   2703216            10397          13244      DL          19
# 2702217   2703217            10397          13487      DL          19
#
#          dayofweek  departuredelay  arrivaldelay
# 0                5              -3             1
# ...

# %%
df.to_csv('flights_final.csv',index=False)
